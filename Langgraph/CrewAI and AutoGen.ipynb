# %%
# !pip install crewai==0.80.0 -q
# !pip install langchain-groq==0.2.1 -q
# !pip install fpdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 49.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# The previous `pip install` command resulted in dependency conflicts. This is often caused by different packages requiring different versions of a shared dependency (in this case, `langchain-core`).
#
# To fix this, I'll uninstall the conflicting `langchain` related packages and then reinstall the necessary ones (`langchain-groq` and `crewai`). This should allow `pip` to install compatible versions of all dependencies.

# %%
# Uninstall conflicting packages
# !pip uninstall -y langchain langchain-core langgraph-prebuilt langgraph langgraph-sdk

# Reinstall the required packages
# !pip install crewai==0.80.0 -q
# !pip install langchain-groq==0.2.1 -q
# !pip install fpdf -q

print("Reinstallation complete. Please check for any new dependency warnings.")
# Out:
# Found existing installation: langchain 1.3.6
# Uninstalling langchain-1.3.6:
#   Successfully uninstalled langchain-1.3.6
# Found existing installation: langchain-core 0.3.86
# Uninstalling langchain-core-0.3.86:
#   Successfully uninstalled langchain-core-0.3.86
# Found existing installation: langgraph-prebuilt 1.1.0
# Uninstalling langgraph-prebuilt-1.1.0:
#   Successfully uninstalled langgraph-prebuilt-1.1.0
# Found existing installation: langgraph 1.2.4
# Uninstalling langgraph-1.2.4:
#   Successfully uninstalled langgraph-1.2.4
# Found existing installation: langgraph-sdk 0.4.2
# Uninstalling langgraph-sdk-0.4.2:
#   Successfully uninstalled langgraph-sdk-0.4.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.2/246.2 kB 19.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# It appears that even after the reinstallation, there are still conflicts with `langchain-core`.
# Specifically, `langchain-groq 0.2.1` expects `langchain-core<0.4.0,>=0.3.15`, but a newer version (1.4.7) was installed.
#
# To resolve this, I will perform a more targeted reinstallation:
# 1. Uninstall all potentially conflicting `langchain` related packages again.
# 2. Explicitly install `langchain-core==0.3.15`.
# 3. Then, reinstall `langchain-groq==0.2.1` and `crewai==0.80.0`.
# 4. Finally, install `fpdf`.

# %%
# Uninstall all potentially conflicting packages
# !pip uninstall -y langchain langchain-core langchain-groq crewai langgraph-prebuilt langgraph langgraph-sdk

# Explicitly install the compatible langchain-core version
# !pip install langchain-core==0.3.15 -q

# Reinstall the required packages
# !pip install crewai==0.80.0 -q
# !pip install langchain-groq==0.2.1 -q
# !pip install fpdf -q

print("Dependency resolution attempt complete. Please check the output for any new warnings.")
# Out:
# Found existing installation: langchain 1.3.9
# Uninstalling langchain-1.3.9:
#   Successfully uninstalled langchain-1.3.9
# Found existing installation: langchain-core 0.3.86
# Uninstalling langchain-core-0.3.86:
#   Successfully uninstalled langchain-core-0.3.86
# Found existing installation: langchain-groq 0.2.1
# Uninstalling langchain-groq-0.2.1:
#   Successfully uninstalled langchain-groq-0.2.1
# Found existing installation: crewai 0.80.0
# Uninstalling crewai-0.80.0:
#   Successfully uninstalled crewai-0.80.0
# Found existing installation: langgraph-prebuilt 1.1.0
# Uninstalling langgraph-prebuilt-1.1.0:
#   Successfully uninstalled langgraph-prebuilt-1.1.0
# Found existing installation: langgraph 1.2.5
# Uninstalling langgraph-1.2.5:
#   Successfully uninstalled langgraph-1.2.5
# Found existing installation: langgraph-sdk 0.4.2
# Uninstalling langgraph-sdk-0.4.2:
#   Successfully uninstalled langgraph-sdk-0.4.2
# ...

# %%
import crewai
import langchain_groq
import asyncio

print("CrewAI OK")
print("LangChain Groq OK")
# Out:
# CrewAI OK
# LangChain Groq OK

# %%
GROQ_API_KEY = ""

# %%
from crewai import LLM

llm = LLM(
  model="groq/llama-3.1-8b-instant",
  api_key=GROQ_API_KEY
)

# %%
from crewai import Agent, Task, Crew, Process

travel_researcher = Agent(
  role="Travel Researcher",
  goal="Find the best tourist attractions in Goa",
  backstory="You are an experienced travel expert.",
  llm=llm,
  verbose=True
)

# %%
research_task = Task(
    description="""
    Find 5 popular tourist places in Goa.
    Mention why tourists visit them.
    """,
    expected_output="List of 5 tourist attractions with explanations.",
    agent=travel_researcher
)

crew = Crew(
    agents=[travel_researcher],
    tasks=[research_task],
    process=Process.sequential,
    verbose=True
)

result = crew.kickoff()

print("\nFINAL RESULT:\n")
print(result)
# Out:
# # Agent: Travel Researcher
# ## Task:
#     Find 5 popular tourist places in Goa.
#     Mention why tourists visit them.
#
#
#
# # Agent: Travel Researcher
# ## Final Answer:
# **Top 5 Popular Tourist Places in Goa**
#
# 1. **Palolem Beach**: This stunning beach is a must-visit destination in Goa. Tourists visit Palolem Beach for its breathtaking views of the crystal-clear waters, white sand, and palm trees. The beach is also a great spot for swimming, sunbathing, and relaxing. Additionally, tourists can enjoy water sports like snorkeling, diving, and kayaking in the nearby waters.
#
# 2. **Bagalong Wildlife Sanctuary**: Located in the dense forests of Goa, the Baga Wildlife Sanctuary is a popular tourist destination for nature lovers. The sanctuary is home to a wide variety of flora and fauna, including crocodiles, deer, and over 150 species of birds. Tourists visit the sanctuary to explore its lush green forests, observe the wildlife, and enjoy trekking and cycling trails.
#
# ...

# %%
from crewai import Agent, Task, Crew, Process, LLM

# LLM
llm = LLM(
    model="groq/llama-3.1-8b-instant", # Reverted model to a working version
    api_key=GROQ_API_KEY
)

# Agent 1
skill_analyzer = Agent(
    role="Skill Analyzer",
    goal="Analyze student skills and strengths",
    backstory="You are an expert in evaluating student abilities.",
    llm=llm,
    verbose=True
)

# Agent 2
career_advisor = Agent(
    role="Career Advisor",
    goal="Suggest suitable career paths",
    backstory="You help students choose careers.",
    llm=llm,
    verbose=True
)

# Agent 3
learning_mentor = Agent(
    role="Learning Mentor",
    goal="Create a learning roadmap",
    backstory="You design study plans and learning paths.",
    llm=llm,
    verbose=True
)

# Task 1
analysis_task = Task(
    description="""
    Student Details:

    Skills:
    - Python
    - SQL
    - Communication

    Interests:
    - Artificial Intelligence
    - Data Science

    Analyze strengths and weaknesses.
    """,
    expected_output="Detailed skill analysis.",
    agent=skill_analyzer
)

# Task 2
career_task = Task(
    description="""
    Based on the student's skills and interests,
    recommend suitable career options.
    """,
    expected_output="List of career recommendations.",
    agent=career_advisor
)

# Task 3
roadmap_task = Task(
    description="""
    Create a 6-month roadmap for the student
    to become job-ready.
    """,
    expected_output="Detailed learning roadmap.",
    agent=learning_mentor
)

crew = Crew(
    agents=[
        skill_analyzer,
        career_advisor,
        learning_mentor
    ],
    tasks=[
        analysis_task,
        career_task,
        roadmap_task
    ],
    process=Process.sequential,
    verbose=True
)

result = crew.kickoff()

print("\nFINAL RESULT:\n")
print(result)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Skill Analyzer
# ## Task:
#     Student Details:
#
#     Skills:
#     - Python
#     - SQL
#     - Communication
#
#     Interests:
#     - Artificial Intelligence
#     - Data Science
#
#     Analyze strengths and weaknesses.
#
#
#
# # Agent: Skill Analyzer
# ## Final Answer:
# **Detailed Skill Analysis Report**
#
# **Student Name:** [Insert Student Name]
#
# **Skills:**
#
# * Python: Proficient
# * SQL: Proficient
# * Communication: Proficient
#
# **Interests:**
#
# * Artificial Intelligence
# * Data Science
#
# **Strengths:**
#
# * Strong foundation in Python, SQL, and Communication.
# * Understanding of AI concepts like machine learning, deep learning, and computer vision.
# * Familiarity with popular AI frameworks and libraries like TensorFlow, PyTorch, and Keras.
# * Experience with NLP techniques and applications.
# ...
